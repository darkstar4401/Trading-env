# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np

MAX_STEPS = 20000
class TradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(TradingEnv, self).__init__()
        self.last_sig = 0
        self.usdt_holdings = 1000
        self.btc_holdings = 0
        self.current_step = 0
        self.prev_usdt,self.prev_btc = 0,0
        #self.init_btc = self.btc_holdings
        self.max_btc = 0
        self.max_usdt = 0
        self.btc_returns = 0
        self.current_act = 0
        

        self.df = df
        # Actions of the format Buy x%, Sell x%, Hold, etc.
        self.action_space = spaces.Box(
            low=np.array([0, 0]), high=np.array([3, 1]), dtype=np.float16)

        # Prices contains the OHCL values for the last five prices
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(6, 6), dtype=np.float16)
        

    def _next_observation(self):
        # Get the stock data points for the last 5 days and scale to between 0-1
        frame = np.array([
            self.df["Open"].iloc[self.current_step],
            self.df["High"].iloc[self.current_step],
            self.df["Low"].iloc[self.current_step],
            self.df["Close"].iloc[self.current_step],
            self.df["Volume"].iloc[self.current_step],
        ])

        # Append additional data and scale each value to between 0-1
        #print(self.total_sales_value / (MAX_NUM_SHARES * MAX_SHARE_PRICE))
        """obs = np.append(frame, [[
            self.balance / 1,
            self.max_net_worth / MAX_ACCOUNT_BALANCE,
            self.shares_held / MAX_NUM_SHARES,
            self.cost_basis / MAX_SHARE_PRICE,
            self.total_shares_sold / MAX_NUM_SHARES,
            self.total_sales_value / (MAX_NUM_SHARES * MAX_SHARE_PRICE),
        ]], axis=0)"""
        return frame

    def _take_action(self, action):
        # Set the current price to a random price within the time step
        current_price = random.uniform(self.df["Open"].iloc[self.current_step], self.df["Close"].iloc[self.current_step])
        #print(current_price,self.df["Open"].iloc[self.current_step])
        action_type = action[0]
        self.current_act = action_type
        amount = action[1]
        #BUY condition
        if (action_type > 0 and self.usdt_holdings !=0 and self.last_sig!=action_type ):
            
            # Buy amount % of balance in shares
            total_possible = float(self.usdt_holdings / current_price)
            self.usdt_holdings = self.usdt_holdings -(total_possible*current_price)
            total_possible = round(total_possible,5)
            #update balances
            self.btc_holdings = total_possible
            if total_possible > self.max_btc:
                self.max_btc = self.btc_holdings
            print("buying {}btc at {}".format(total_possible,str(current_price)))
            print("{} remaining usdt".format(self.usdt_holdings))
            print("\n====\n")
            

        elif (action_type < 0 and self.btc_holdings !=0 and self.last_sig!=action_type):
            # Buy amount % of balance in shares
            total_possible = float(self.btc_holdings)#/float(last_price["bidPrice"])
            
            #update balances
            self.btc_holdings = self.btc_holdings -self.btc_holdings
            self.usdt_holdings = float(total_possible*current_price)
            if self.usdt_holdings > self.max_usdt:
                self.max_usdt = self.usdt_holdings
            print("Selling {}btc at {}".format(total_possible,str(current_price)))
            print("{} remaining usdt".format(self.usdt_holdings))
            print("\n====\n")
            
            
        self.last_sig  = action[0]
        if(self.btc_holdings!=0):
            self.btc_net = (self.btc_holdings/self.init_btc)*100

        if self.btc_holdings > self.max_btc:
            self.max_btc = self.btc_holdings
        if self.btc_holdings>0:
            curr_profit = (self.btc_holdings/ self.init_btc)
            #print(self.btc_holdings,self.init_btc)
        else:
            #print("USDT: {}  Init btc: {}".format(self.usdt_holdings,self.init_btc))
            if(self.usdt_holdings != self.prev_usdt):
                print("USDT: {}  Init btc: {}".format(self.usdt_holdings,self.init_btc))
            self.prev_usdt,self.prev_btc = self.usdt_holdings,self.btc_holdings
            #print("Current profit: ",curr_profit)


    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        if self.current_step > len(self.df['Open'].values) - 6:
            self.current_step = 0

        delay_modifier = (self.current_step / MAX_STEPS)

        #reward = self.btc_net
        done = (self.btc_holdings/self.init_btc == 0 and self.usdt_holdings==0)

        obs = self._next_observation()

        return obs,  done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        self.usdt_holdings = 1000
        self.btc_holdings = 0
        self.max_usdt = self.usdt_holdings
        self.max_btc = 0
        self.max_usdt = 0
        self.btc_returns = 0
        self.current_act = 0
        self.init_btc = (self.usdt_holdings/df['Open'].iloc[self.current_step])

        # Set the current step to a random point within the data frame
        #print(self.df.columns)
        self.current_step = random.randint(
            0, len(self.df['Open'].values) - 6)

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        profit = (self.btc_holdings/ self.init_btc)
        if(profit>0):
            profit*=100
        else:
            profit = (1-profit)
        max_curr = (self.max_btc*self.df['Open'].iloc[-1])
        
        
        print(f'Step: {self.current_step}')
        print(f'BTC Balance: {self.btc_holdings}')
        print("USDT Balance: {}".format(self.usdt_holdings))
        print('Max usdt: {}'.format(self.max_usdt))
        print(f'Max btc: {self.max_btc}')
        print('Max btc at current price: {}'.format(max_curr))
        print(f'Profit: {profit}')
        #print(df.iloc[self.current_step].index)
        return {"USDT":self.usdt_holdings,"BTC":self.btc_holdings}

# %%
import gym
import json
import datetime as dt

#from env.TradingEnv import TradingEnv

import pandas as pd
import portmaker

end = int(portmaker.current_milli_time())
d_intv = 90
st = end-(86400000*d_intv)
coin = "BTCUSDT"
candle_k='5m'
data = portmaker.get_data(coin,st,end,candle_k)
t1 = portmaker.current_milli_time()
all_prices,df = portmaker.get_intv(data,coin,d_intv,candle_k)
print(df.columns)
all_sigs = df.set_index("Close time") 
# The algorithms require a vectorized environment to run
# Out:
# Creating: 3 day intervals over 90 days data
# Using 5m granualarity
# 2019-05-17 07:05:00 2019-05-20 07:05:00
# 2019-05-20 07:05:00 2019-05-23 07:05:00
# 2019-05-23 07:05:00 2019-05-26 07:05:00
# 2019-05-26 07:05:00 2019-05-29 07:05:00
# 2019-05-29 07:05:00 2019-06-01 07:05:00
# 2019-06-01 07:05:00 2019-06-04 07:05:00
# 2019-06-04 07:05:00 2019-06-07 07:05:00
# 2019-06-07 07:05:00 2019-06-10 08:05:00
# 2019-06-10 08:05:00 2019-06-13 08:05:00
# 2019-06-13 08:05:00 2019-06-16 08:05:00
# 2019-06-16 08:05:00 2019-06-19 08:05:00
# 2019-06-19 08:05:00 2019-06-22 08:05:00
# 2019-06-22 08:05:00 2019-06-25 08:05:00
# 2019-06-25 08:05:00 2019-06-28 08:05:00
# 2019-06-28 08:05:00 2019-07-01 08:05:00
# 2019-07-01 08:05:00 2019-07-04 08:05:00
# 2019-07-04 08:05:00 2019-07-07 08:05:00
# 2019-07-07 08:05:00 2019-07-10 08:05:00
# 2019-07-10 08:05:00 2019-07-13 08:05:00
# 2019-07-13 08:05:00 2019-07-16 08:05:00
# 2019-07-16 08:05:00 2019-07-19 08:05:00
# 2019-07-19 08:05:00 2019-07-22 08:05:00
# 2019-07-22 08:05:00 2019-07-25 08:05:00
# 2019-07-25 08:05:00 2019-07-28 08:05:00
# 2019-07-28 08:05:00 2019-07-31 08:05:00
# 2019-07-31 08:05:00 2019-08-03 08:05:00
# 2019-08-03 08:05:00 2019-08-06 08:05:00
# 2019-08-06 08:05:00 2019-08-09 08:05:00
# 2019-08-09 08:05:00 2019-08-12 08:05:00
# 2019-08-12 08:05:00 2019-08-15 00:03:17.579000
# Index(['Open', 'High', 'Low', 'Close', 'Close time', 'Volume', '-1', '2', '1',
#        '-2', 'Short', 'Long', 'Position', 'pos_diff'],
#       dtype='object')

# %%
env = TradingEnv(df)
#model = PPO2(MlpPolicy, env, verbose=1)
#model.learn(total_timesteps=20000)
max_iter = 10000
obs = env.reset()
rc = 1
for i in range(max_iter):
    rand_agent = np.random.randint(-1,2)
    BWA_sig = env.df.Position.iloc[env.current_step]
    #print(rc==(max_iter),rc)
    if(rc%500==0 or rc==max_iter):
        print("\n========================\n")
        env.render()
    
    #random agent for testing
    #obs, done, info = env.step([rand_agent,1])
    #portmaker signal for benchmark
    obs, done, info = env.step([BWA_sig,1])
    rc+=1
# Out:
# USDT: 1000  Init btc: 0.13719717154311148
# buying 0.12958btc at 7717.523881141874
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12958btc at 7718.001355869524
# 1000.0986156935729 remaining usdt
#
# ====
#
# USDT: 1000.0986156935729  Init btc: 0.13719717154311148
# buying 0.13004btc at 7690.924566552964
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13004btc at 7697.259497359661
# 1000.9516250366502 remaining usdt
#
# ====
#
# USDT: 1000.9516250366502  Init btc: 0.13719717154311148
# buying 0.13031btc at 7681.222508083003
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13031btc at 7688.442126131922
# 1001.8808934562509 remaining usdt
#
# ====
#
# USDT: 1001.8808934562509  Init btc: 0.13719717154311148
# buying 0.13093btc at 7651.901306044829
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13093btc at 7752.9728773092265
# 1015.096738826097 remaining usdt
#
# ====
#
# USDT: 1015.096738826097  Init btc: 0.13719717154311148
# buying 0.12978btc at 7821.926657043463
# 1.1368683772161603e-13 remaining usdt
#
# ====
#
# Selling 0.12978btc at 7916.21031371552
# 1027.3657745140001 remaining usdt
#
# ====
#
# USDT: 1027.3657745140001  Init btc: 0.13719717154311148
# buying 0.12989btc at 7909.460808353517
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12989btc at 7922.8078192905095
# 1029.0935076476444 remaining usdt
#
# ====
#
# USDT: 1029.0935076476444  Init btc: 0.13719717154311148
# buying 0.12912btc at 7969.912504529944
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12912btc at 7946.251660683792
# 1026.0200144274913 remaining usdt
#
# ====
#
# USDT: 1026.0200144274913  Init btc: 0.13719717154311148
# buying 0.12853btc at 7982.88303388849
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12853btc at 7961.400500001329
# 1023.2788062651709 remaining usdt
#
# ====
#
# USDT: 1023.2788062651709  Init btc: 0.13719717154311148
# buying 0.13168btc at 7771.036685268418
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 7414
# BTC Balance: 0.13168
# USDT Balance: 0.0
# Max usdt: 1029.0935076476444
# Max btc: 0.13168
# Max btc at current price: 1324.0634687999998
# Profit: 95.97865503999998
# Selling 0.13168btc at 7951.253761365696
# 1047.0210952966347 remaining usdt
#
# ====
#
# USDT: 1047.0210952966347  Init btc: 0.13719717154311148
# buying 0.13089btc at 7999.000106420375
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13089btc at 7949.569675137589
# 1040.5191747787592 remaining usdt
#
# ====
#
# USDT: 1040.5191747787592  Init btc: 0.13719717154311148
# buying 0.13074btc at 7958.546765841586
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13074btc at 7952.238179659296
# 1039.6756196086565 remaining usdt
#
# ====
#
# USDT: 1039.6756196086565  Init btc: 0.13719717154311148
# buying 0.13052btc at 7965.395772603238
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13052btc at 7954.663607596975
# 1038.242694063557 remaining usdt
#
# ====
#
# USDT: 1038.242694063557  Init btc: 0.13719717154311148
# buying 0.13013btc at 7978.780569989924
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13013btc at 7961.497763466057
# 1036.029703959838 remaining usdt
#
# ====
#
# USDT: 1036.029703959838  Init btc: 0.13719717154311148
# buying 0.12994btc at 7973.075707320071
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12994btc at 7970.8432307853445
# 1035.7313694082477 remaining usdt
#
# ====
#
# USDT: 1035.7313694082477  Init btc: 0.13719717154311148
# buying 0.12996btc at 7969.761252572556
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12996btc at 7956.97568807396
# 1034.0885604220916 remaining usdt
#
# ====
#
# USDT: 1034.0885604220916  Init btc: 0.13719717154311148
# buying 0.12971btc at 7972.2851927269085
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12971btc at 7953.159561525463
# 1031.6043267254677 remaining usdt
#
# ====
#
# USDT: 1031.6043267254677  Init btc: 0.13719717154311148
# buying 0.12924btc at 7981.793423729845
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12924btc at 8090.777080919887
# 1045.6520299380861 remaining usdt
#
# ====
#
# USDT: 1045.6520299380861  Init btc: 0.13719717154311148
# buying 0.12928btc at 8087.9631071194
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12928btc at 8097.013938657967
# 1046.781961989702 remaining usdt
#
# ====
#
# USDT: 1046.781961989702  Init btc: 0.13719717154311148
# buying 0.12924btc at 8099.474573974724
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12924btc at 8090.18361503637
# 1045.5753304073003 remaining usdt
#
# ====
#
# USDT: 1045.5753304073003  Init btc: 0.13719717154311148
# buying 0.1292btc at 8092.874335979882
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1292btc at 8092.282094587401
# 1045.5228466206922 remaining usdt
#
# ====
#
# USDT: 1045.5228466206922  Init btc: 0.13719717154311148
# buying 0.12926btc at 8088.786866137396
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12926btc at 8088.396749577533
# 1045.506163850392 remaining usdt
#
# ====
#
# USDT: 1045.506163850392  Init btc: 0.13719717154311148
# buying 0.12937btc at 8081.452848906701
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12937btc at 8085.019631264472
# 1045.958989696685 remaining usdt
#
# ====
#
# USDT: 1045.958989696685  Init btc: 0.13719717154311148
# buying 0.12957btc at 8072.26054460287
# 0.0 remaining usdt
#
# ====
#
# Selling 0.12957btc at 8097.036886370065
# 1049.1330693669693 remaining usdt
#
# ====
#
# USDT: 1049.1330693669693  Init btc: 0.13719717154311148
# buying 0.13028btc at 8053.130207917352
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13028btc at 8108.501024760497
# 1056.3755135057977 remaining usdt
#
# ====
#
# USDT: 1056.3755135057977  Init btc: 0.13719717154311148
# buying 0.13021btc at 8112.729300309868
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 7914
# BTC Balance: 0.13021
# USDT Balance: 0.0
# Max usdt: 1056.3755135057977
# Max btc: 0.13168
# Max btc at current price: 1324.0634687999998
# Profit: 94.90720437999998
# Selling 0.13021btc at 8228.543691920258
# 1071.4386741249368 remaining usdt
#
# ====
#
# USDT: 1071.4386741249368  Init btc: 0.13719717154311148
# buying 0.13001btc at 8241.20694812212
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13001btc at 8254.797065154737
# 1073.2061664407672 remaining usdt
#
# ====
#
# USDT: 1073.2061664407672  Init btc: 0.13719717154311148
# buying 0.12968btc at 8275.589932990195
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 8414
# BTC Balance: 0.12968
# USDT Balance: 0.0
# Max usdt: 1073.2061664407672
# Max btc: 0.13168
# Max btc at current price: 1324.0634687999998
# Profit: 94.52089903999999
# Selling 0.12968btc at 9253.908533872373
# 1200.0468586725692 remaining usdt
#
# ====
#
# USDT: 1200.0468586725692  Init btc: 0.13719717154311148
# buying 0.13213btc at 9082.09283557788
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13213btc at 9078.404588341675
# 1199.5295982575853 remaining usdt
#
# ====
#
# USDT: 1199.5295982575853  Init btc: 0.13719717154311148
# buying 0.1324btc at 9059.772673410467
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1324btc at 8970.908338224592
# 1187.748263980936 remaining usdt
#
# ====
#
# USDT: 1187.748263980936  Init btc: 0.13719717154311148
# buying 0.13181btc at 9010.81954569306
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13181btc at 9154.355617987047
# 1206.6356140068726 remaining usdt
#
# ====
#
# USDT: 1206.6356140068726  Init btc: 0.13719717154311148
# buying 0.13121btc at 9195.955427373989
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.13121btc at 9179.567478816161
# 1204.4510488954684 remaining usdt
#
# ====
#
# USDT: 1204.4510488954684  Init btc: 0.13719717154311148
# buying 0.13351btc at 9021.572849904744
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13351btc at 9037.9383087518
# 1206.6551436014527 remaining usdt
#
# ====
#
# USDT: 1206.6551436014527  Init btc: 0.13719717154311148
# buying 0.13397btc at 9007.13674529636
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13397btc at 9016.1315589967
# 1207.891144958788 remaining usdt
#
# ====
#
# USDT: 1207.891144958788  Init btc: 0.13719717154311148
# buying 0.13315btc at 9071.756498011373
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13315btc at 9037.961299751523
# 1203.4045470619153 remaining usdt
#
# ====
#
# USDT: 1203.4045470619153  Init btc: 0.13719717154311148
# buying 0.13335btc at 9024.67454492704
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13335btc at 9026.632527918102
# 1203.7014475978788 remaining usdt
#
# ====
#
# USDT: 1203.7014475978788  Init btc: 0.13719717154311148
# buying 0.13336btc at 9025.728759424415
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13336btc at 9025.529705471015
# 1203.6446415216146 remaining usdt
#
# ====
#
# USDT: 1203.6446415216146  Init btc: 0.13719717154311148
# buying 0.13416btc at 8971.858008806083
# -2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.13416btc at 8991.16132135034
# 1206.2542028723617 remaining usdt
#
# ====
#
# USDT: 1206.2542028723617  Init btc: 0.13719717154311148
# buying 0.13415btc at 8991.60714943223
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13415btc at 8986.794442690805
# 1205.5784744869713 remaining usdt
#
# ====
#
# USDT: 1205.5784744869713  Init btc: 0.13719717154311148
# buying 0.13424btc at 8980.96965164136
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13424btc at 8959.81032177033
# 1202.764937594449 remaining usdt
#
# ====
#
# USDT: 1202.764937594449  Init btc: 0.13719717154311148
# buying 0.13365btc at 8999.459059582041
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13365btc at 9154.697417094205
# 1223.5253097946404 remaining usdt
#
# ====
#
# USDT: 1223.5253097946404  Init btc: 0.13719717154311148
# buying 0.13319btc at 9186.40486671352
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13319btc at 9161.865633876676
# 1220.2688837760345 remaining usdt
#
# ====
#
# USDT: 1220.2688837760345  Init btc: 0.13719717154311148
# buying 0.13311btc at 9167.239866216107
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13311btc at 9156.286300964563
# 1218.793269521393 remaining usdt
#
# ====
#
# USDT: 1218.793269521393  Init btc: 0.13719717154311148
# buying 0.1329btc at 9170.568503101755
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1329btc at 9165.042343856125
# 1218.034127498479 remaining usdt
#
# ====
#
# USDT: 1218.034127498479  Init btc: 0.13719717154311148
#
# ========================
#
# Step: 8914
# BTC Balance: 0.0
# USDT Balance: 1218.034127498479
# Max usdt: 1223.5253097946404
# Max btc: 0.13424
# Max btc at current price: 1349.8046784
# Profit: 1.0
# buying 0.13212btc at 9219.2540958236
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13212btc at 9222.64514833488
# 1218.4958769980042 remaining usdt
#
# ====
#
# USDT: 1218.4958769980042  Init btc: 0.13719717154311148
# buying 0.13214btc at 9221.544112939859
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13214btc at 9231.124074571555
# 1219.8007352138854 remaining usdt
#
# ====
#
# USDT: 1219.8007352138854  Init btc: 0.13719717154311148
# buying 0.13201btc at 9240.06513694548
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13201btc at 9229.283994617059
# 1218.3577801293977 remaining usdt
#
# ====
#
# USDT: 1218.3577801293977  Init btc: 0.13719717154311148
# buying 0.13174btc at 9248.027391536702
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13174btc at 9261.019584061987
# 1220.046720004326 remaining usdt
#
# ====
#
# USDT: 1220.046720004326  Init btc: 0.13719717154311148
# buying 0.1315btc at 9277.779952388557
# 0.0 remaining usdt
#
# ====
# Selling 0.1315btc at 9260.577249765714
# 1217.7659083441915 remaining usdt
#
# ====
#
# USDT: 1217.7659083441915  Init btc: 0.13719717154311148
# buying 0.1345btc at 9054.194884414192
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1345btc at 9048.476098714336
# 1217.0200352770783 remaining usdt
#
# ====
#
# USDT: 1217.0200352770783  Init btc: 0.13719717154311148
# buying 0.1342btc at 9069.006279837613
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1342btc at 9068.785096005648
# 1217.030959883958 remaining usdt
#
# ====
#
# USDT: 1217.030959883958  Init btc: 0.13719717154311148
# buying 0.13446btc at 9051.343685266302
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13446btc at 9079.276990665594
# 1220.7995841648958 remaining usdt
#
# ====
#
# USDT: 1220.7995841648958  Init btc: 0.13719717154311148
# buying 0.13481btc at 9055.65290791069
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13481btc at 9056.345986492712
# 1220.8860024390826 remaining usdt
#
# ====
#
# USDT: 1220.8860024390826  Init btc: 0.13719717154311148
# buying 0.135btc at 9043.88552057925
# 0.0 remaining usdt
#
# ====
#
# Selling 0.135btc at 9043.992710589124
# 1220.9390159295317 remaining usdt
#
# ====
#
# USDT: 1220.9390159295317  Init btc: 0.13719717154311148
# buying 0.13491btc at 9050.036442689552
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13491btc at 9052.326004313363
# 1221.2493012419159 remaining usdt
#
# ====
#
# USDT: 1221.2493012419159  Init btc: 0.13719717154311148
# buying 0.13489btc at 9053.369902127206
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 9414
# BTC Balance: 0.13489
# USDT Balance: 0.0
# Max usdt: 1223.5253097946404
# Max btc: 0.135
# Max btc at current price: 1357.4466
# Profit: 98.31835342000001
# Selling 0.13489btc at 9055.275621020426
# 1221.4661285194454 remaining usdt
#
# ====
#
# USDT: 1221.4661285194454  Init btc: 0.13719717154311148
# buying 0.13463btc at 9073.032761956363
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13463btc at 9159.445492255649
# 1233.136146622378 remaining usdt
#
# ====
#
# USDT: 1233.136146622378  Init btc: 0.13719717154311148
# buying 0.13463btc at 9159.648894919346
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13463btc at 9156.138415817295
# 1232.6909149214823 remaining usdt
#
# ====
#
# USDT: 1232.6909149214823  Init btc: 0.13719717154311148
# buying 0.13461btc at 9157.470728203467
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13461btc at 9154.733793904445
# 1232.3187159974773 remaining usdt
#
# ====
#
# USDT: 1232.3187159974773  Init btc: 0.13719717154311148
# buying 0.13514btc at 9118.752119995945
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13514btc at 9114.85575877135
# 1231.7816072403602 remaining usdt
#
# ====
#
# USDT: 1231.7816072403602  Init btc: 0.13719717154311148
# buying 0.13518btc at 9111.964524770874
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.13518btc at 9109.485974879068
# 1231.4203140841523 remaining usdt
#
# ====
#
# USDT: 1231.4203140841523  Init btc: 0.13719717154311148
# buying 0.13508btc at 9116.325430174042
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13508btc at 9108.18055536315
# 1230.3330294184543 remaining usdt
#
# ====
#
# USDT: 1230.3330294184543  Init btc: 0.13719717154311148
# buying 0.13503btc at 9111.336842184364
# -2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.13503btc at 9097.532206184664
# 1228.4397738011153 remaining usdt
#
# ====
#
# USDT: 1228.4397738011153  Init btc: 0.13719717154311148
# buying 0.13502btc at 9097.9287826777
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13502btc at 9078.81287554558
# 1225.8213144561641 remaining usdt
#
# ====
#
# USDT: 1225.8213144561641  Init btc: 0.13719717154311148
# buying 0.13481btc at 9093.09269073463
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13481btc at 9068.967280812918
# 1222.5874791263896 remaining usdt
#
# ====
#
# USDT: 1222.5874791263896  Init btc: 0.13719717154311148
# buying 0.13464btc at 9080.350289559663
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13464btc at 9090.218661031002
# 1223.9070405212142 remaining usdt
#
# ====
#
# USDT: 1223.9070405212142  Init btc: 0.13719717154311148
# buying 0.13465btc at 9089.466669136817
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13465btc at 9144.825969385194
# 1231.3508167777163 remaining usdt
#
# ====
#
# USDT: 1231.3508167777163  Init btc: 0.13719717154311148
# buying 0.13457btc at 9150.08654218799
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13457btc at 9150.889274464345
# 1231.435169664667 remaining usdt
#
# ====
#
# USDT: 1231.435169664667  Init btc: 0.13719717154311148
# buying 0.13464btc at 9146.120806330226
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13464btc at 9133.173600145885
# 1229.690493523642 remaining usdt
#
# ====
#
# USDT: 1229.690493523642  Init btc: 0.13719717154311148
# buying 0.13426btc at 9159.102095288883
# 0.0 remaining usdt
#
# ====
#
# Selling 0.13426btc at 9271.086719404333
# 1244.7361029472256 remaining usdt
#
# ====
#
# USDT: 1244.7361029472256  Init btc: 0.13719717154311148
# buying 0.13394btc at 9293.231645802058
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step:
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.14586btc at 11777.0691526513
# 1717.8033066057185 remaining usdt
#
# ====
#
# USDT: 1717.8033066057185  Init btc: 0.13719717154311148
# buying 0.14638btc at 11735.127468382096
# 0.0 remaining usdt
#
# ====
#
# Selling 0.14638btc at 11766.314287874276
# 1722.3530854590367 remaining usdt
#
# ====
#
# USDT: 1722.3530854590367  Init btc: 0.13719717154311148
# buying 0.1461btc at 11789.113171448002
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1461btc at 11781.615680659314
# 1721.2940509443258 remaining usdt
#
# ====
#
# USDT: 1721.2940509443258  Init btc: 0.13719717154311148
# buying 0.1468btc at 11725.526261409508
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1468btc at 11708.116663475907
# 1718.7515261982633 remaining usdt
#
# ====
#
# USDT: 1718.7515261982633  Init btc: 0.13719717154311148
# ========================
#
# Step: 12914
# BTC Balance: 0.0
# USDT Balance: 1718.7515261982633
# Max usdt: 1806.8647423722357
# Max btc: 0.1468
# Max btc at current price: 1476.097488
# Profit: 1.0
# buying 0.15653btc at 10980.068654736997
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.15653btc at 11006.890346375887
# 1722.9085459182177 remaining usdt
#
# ====
#
# USDT: 1722.9085459182177  Init btc: 0.13719717154311148
# buying 0.15576btc at 11061.307284215443
# 0.0 remaining usdt
#
# ====
#
# Selling 0.15576btc at 11115.90941301804
# 1731.41405017169 remaining usdt
#
# ====
#
# USDT: 1731.41405017169  Init btc: 0.13719717154311148
# buying 0.15747btc at 10995.07645570592
# 0.0 remaining usdt
#
# ====
#
# Selling 0.15747btc at 10993.260569293245
# 1731.1087418466072 remaining usdt
#
# ====
#
# USDT: 1731.1087418466072  Init btc: 0.13719717154311148
# buying 0.15754btc at 10988.190151755136
# 0.0 remaining usdt
#
# ====
#
# Selling 0.15754btc at 10967.860196030348
# 1727.876695282621 remaining usdt
#
# ====
#
# USDT: 1727.876695282621  Init btc: 0.13719717154311148
# buying 0.15755btc at 10966.822737175904
# 0.0 remaining usdt
#
# ====
#
# Selling 0.15755btc at 10999.437668112443
# 1732.9614046111153 remaining usdt
#
# ====
#
# USDT: 1732.9614046111153  Init btc: 0.13719717154311148
# buying 0.15796btc at 10970.886480055686
# 0.0 remaining usdt
#
# ====
#
# Selling 0.15796btc at 10979.427043332867
# 1734.3102957648596 remaining usdt
#
# ====
#
# USDT: 1734.3102957648596  Init btc: 0.13719717154311148
# buying 0.15798btc at 10978.283895221395
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.15798btc at 10909.274759390768
# 1723.4472264885537 remaining usdt
#
# ====
#
# USDT: 1723.4472264885537  Init btc: 0.13719717154311148
# buying 0.16661btc at 10344.47824088612
# 0.0 remaining usdt
#
# ====
#
# Selling 0.16661btc at 10362.464656256792
# 1726.4902363789442 remaining usdt
#
# ====
#
# USDT: 1726.4902363789442  Init btc: 0.13719717154311148
# buying 0.16812btc at 10269.228949694885
# 0.0 remaining usdt
#
# ====
#
# Selling 0.16812btc at 10281.780687663673
# 1728.5729692100167 remaining usdt
#
# ====
#
# USDT: 1728.5729692100167  Init btc: 0.13719717154311148
# buying 0.16816btc at 10279.223715793398
# 2.2737367544323206e-13 remaining usdt
#
# ====
#
# Selling 0.16816btc at 10287.659218611605
# 1729.9727742017276 remaining usdt
#
# ====
#
# USDT: 1729.9727742017276  Init btc: 0.13719717154311148
# buying 0.16834btc at 10276.822751816211
# 0.0 remaining usdt
#
# ====
#
# Selling 0.
# 0.0 remaining usdt
#
# ====
#
# Selling 0.18402btc at 11401.884193535565
# 2098.1747292944146 remaining usdt
#
# ====
#
# USDT: 2098.1747292944146  Init btc: 0.13719717154311148
# buying 0.18321btc at 11452.574940819413
# 0.0 remaining usdt
#
# ====
#
# Selling 0.18321btc at 11408.360025163976
# 2090.125640210292 remaining usdt
#
# ====
#
# USDT: 2090.125640210292  Init btc: 0.13719717154311148
#
# ========================
#
# Step: 14914
# BTC Balance: 0.0
# USDT Balance: 2090.125640210292
# Max usdt: 2104.3806319899973
# Max btc: 0.18534
# Max btc at current price: 1863.6233544
# Profit: 1.0
# buying 0.17711btc at 11801.566199332134
# 0.0 remaining usdt
#
# ====
#
# Selling 0.17711btc at 12441.135610982641
# 2203.4495280611354 remaining usdt
#
# ====
#
# USDT: 2203.4495280611354  Init btc: 0.13719717154311148
# buying 0.17942btc at 12280.760107354543
# 0.0 remaining usdt
#
# ====
#
# Selling 0.17942btc at 12279.59185540994
# 2203.2043706976515 remaining usdt
#
# ====
#
# USDT: 2203.2043706976515  Init btc: 0.13719717154311148
# buying 0.17877btc at 12324.195338151665
# 0.0 remaining usdt
#
# ====
#
# Selling 0.17877btc at 12290.602383712585
# 2197.190988136299 remaining usdt
#
# ====
#
# USDT: 2197.190988136299  Init btc: 0.13719717154311148
# buying 0.17836btc at 12318.534419892363
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 15414
# BTC Balance: 0.17836
# USDT Balance: 0.0
# Max usdt: 2203.4495280611354
# Max btc: 0.18534
# Max btc at current price: 1863.6233544
# Profit: 130.00268007999998
# Selling 0.17836btc at 12555.29106251226
# 2239.361713909687 remaining usdt
#
# ====
#
# USDT: 2239.361713909687  Init btc: 0.13719717154311148
# buying 0.1808btc at 12385.644608361257
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1808btc at 12367.11789655639
# 2235.9749156973953 remaining usdt
#
# ====
#
# USDT: 2235.9749156973953  Init btc: 0.13719717154311148
# buying 0.18011btc at 12414.580095249998
# 0.0 remaining usdt
#
# ====
#
# Selling 0.18011btc at 12874.216015017651
# 2318.7750464648293 remaining usdt
#
# ====
#
# USDT: 2318.7750464648293  Init btc: 0.13719717154311148
# buying 0.18015btc at 12871.453229903074
# 0.0 remaining usdt
#
# ====
#
# Selling 0.18015btc at 12918.498039615213
# 2327.2674218366806 remaining usdt
#
# ====
#
# USDT: 2327.2674218366806  Init btc: 0.13719717154311148
# buying 0.1797btc at 12951.12192639842
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1797btc at 12995.067197690072
# 2335.213575424906 remaining usdt
#
# ====
#
# USDT: 2335.213575424906  Init btc: 0.13719717154311148
# buying 0.17877btc at 13062.931218459451
# 0.0 remaining usdt
#
# ====
#
# Selling 0.17877btc at 13004.698780937862
# 2324.850001068262 remaining usdt
#
# ====
#
# USDT: 2324.850001068262  Init btc: 0.13719717154311148
# buying 0.17815btc at 13049.674879656255
# 0.0 remaining usdt
#
# ====
#
# Selling 0.17815btc at 13044.063942624736
# 2323.7999913785966 remaining usdt
#
# ====
#
# USDT: 2323.7999913785966  Init btc: 0.13719717154311148
# buying 0.19245btc at 12074.64603304763
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19245btc at 12075.791536205254
# 2323.986081142701 remaining usdt
#
# ====
#
# USDT: 2323.986081142701  Init btc: 0.13719717154311148
# buying 0.19188btc at 12111.547880402204
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19188btc at 12073.4541507942
# 2316.654382454391 remaining usdt
#
# ====
#
# USDT: 2316.654382454391  Init btc: 0.13719717154311148
# buying 0.19118btc at 12117.508555169568
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19118btc at 12067.85518118777
# 2307.1325535394776 remaining usdt
#
# ====
#
# USDT: 2307.1325535394776  Init btc: 0.13719717154311148
# buying 0.19121btc at 12065.726993477738
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19121btc at 12051.663817385106
# 2304.398638522206 remaining usdt
#
# ====
#
# USDT: 2304.398638522206  Init btc: 0.13719717154311148
# buying 0.19268btc at 11959.495477600618
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19268btc at 11998.657265613185
# 2311.9012819383483 remaining usdt
#
# ====
#
# USDT: 2311.9012819383483  Init btc: 0.13719717154311148
# buying 0.19314btc at 11970.084016820016
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19314btc at 11961.562769458566
# 2310.2562332932275 remaining usdt
#
# ====
#
# USDT: 2310.2562332932275  Init btc: 0.13719717154311148
# buying 0.1934btc at 11945.242087484203
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1934btc at 11946.859976441363
# 2310.5227194437593 remaining usdt
#
# ====
#
# USDT: 2310.5227194437593  Init btc: 0.13719717154311148
# buying 0.19318btc at 11960.302550616861
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19318btc at 11927.23697967
# 2304.1036397326507 remaining usdt
#
# ====
#
# USDT: 2304.1036397326507  Init btc: 0.13719717154311148
# buying 0.19962btc at 11542.428524452744
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 15914
# BTC Balance: 0.19962
# USDT Balance: 0.0
# Max usdt: 2335.213575424906
# Max btc: 0.19962
# Max btc at current price: 2007.2110392
# Profit: 145.49862635999997
# Selling 0.19962btc at 11490.073674813942
# 2293.648506966359 remaining usdt
#
# ====
#
# USDT: 2293.648506966359  Init btc: 0.13719717154311148
# buying 0.19896btc at 11527.951676317336
# 0.0 remaining usdt
#
# ====
#
# Selling 0.19896btc at 11472.188573590873
# 2282.50663860164 remaining usdt
#
# ====
#
# USDT: 2282.50663860164  Init btc: 0.13719717154311148
# buying 0.20021btc at 11400.68095199434
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20021btc at 11392.326956544193
# 2280.8577799697127 remaining usdt
#
# ====
#
# USDT: 2280.8577799697127  Init btc: 0.13719717154311148
# buying 0.1998btc at 11415.864835749178
# 0.0 remaining usdt
#
# ====
#
# Selling 0.1998btc at 11389.058006915058
# 2275.533789781629 remaining usdt
#
# ====
#
# USDT: 2275.533789781629  Init btc: 0.13719717154311148
# buying 0.20085btc at 11329.584602624203
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20085btc at 11387.541888340424
# 2287.187788273174 remaining usdt
#
# ====
#
# USDT: 2287.187788273174  Init btc: 0.13719717154311148
# buying 0.20079btc at 11391.057605485552
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20079btc at 11345.438906113373
# 2278.0506779585044 remaining usdt
#
# ====
#
# USDT: 2278.0506779585044  Init btc: 0.13719717154311148
# buying 0.20071btc at 11349.922684122666
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20071btc at 11340.869769259674
# 2276.2259713881094 remaining usdt
#
# ====
#
# USDT: 2276.2259713881094  Init btc: 0.13719717154311148
# buying 0.20115btc at 11315.860189348956
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20115btc at 11310.619418824701
# 2275.1310960965884 remaining usdt
#
# ====
#
# USDT: 2275.1310960965884  Init btc: 0.13719717154311148
# buying 0.20111btc at 11312.800824728241
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20111btc at 11301.153763156233
# 2272.77503330835 remaining usdt
#
# ====
#
# USDT: 2272.77503330835  Init btc: 0.13719717154311148
# buying 0.20108btc at 11303.016613093545
# 0.0 remaining usdt
#
# ====
#
#
# ========================
#
# Step: 16414
# BTC Balance: 0.20108
# USDT Balance: 0.0
# Max usdt: 2335.213575424906
# Max btc: 0.20115
# Max btc at current price: 2022.5954339999998
# Profit: 146.56278824
# Selling 0.20108btc at 11548.369044066803
# 2322.146047380953 remaining usdt
#
# ====
#
# USDT: 2322.146047380953  Init btc: 0.13719717154311148
# buying 0.20098btc at 11554.076304228014
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20098btc at 11532.013318157082
# 2317.7040366832102 remaining usdt
#
# ====
#
# USDT: 2317.7040366832102  Init btc: 0.13719717154311148
# buying 0.20103btc at 11529.118243988718
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20103btc at 11499.820891716192
# 2311.808993861706 remaining usdt
#
# ====
#
# USDT: 2311.808993861706  Init btc: 0.13719717154311148
# buying 0.20054btc at 11527.775136559423
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20054btc at 11540.698398274473
# 2314.371656789963 remaining usdt
#
# ====
#
# USDT: 2314.371656789963  Init btc: 0.13719717154311148
# buying 0.20099btc at 11515.055848837792
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20099btc at 11509.93063622685
# 2313.3809585752347 remaining usdt
#
# ====
#
# USDT: 2313.3809585752347  Init btc: 0.13719717154311148
# buying 0.20476btc at 11298.002354931697
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20476btc at 11273.844392631934
# 2308.432377835315 remaining usdt
#
# ====
#
# USDT: 2308.432377835315  Init btc: 0.13719717154311148
# buying 0.20467btc at 11278.89695389959
# 0.0 remaining usdt
#
# ====
# Selling 0.20467btc at 11320.739057388231
# 2317.015662875649 remaining usdt
#
# ====
#
# USDT: 2317.015662875649  Init btc: 0.13719717154311148
# buying 0.20493btc at 11306.433663199492
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20493btc at 11285.543199150034
# 2312.746367801816 remaining usdt
#
# ====
#
# USDT: 2312.746367801816  Init btc: 0.13719717154311148
# buying 0.20732btc at 11155.369600698898
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20732btc at 11161.477433687898
# 2313.997501552175 remaining usdt
#
# ====
#
# USDT: 2313.997501552175  Init btc: 0.13719717154311148
# buying 0.20723btc at 11166.260189351655
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20723btc at 11155.032458473805
# 2311.6573763695264 remaining usdt
#
# ====
#
# USDT: 2311.6573763695264  Init btc: 0.13719717154311148
# buying 0.20727btc at 11153.083808095975
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20727btc at 11142.727089650582
# 2309.553043871876 remaining usdt
#
# ====
#
# USDT: 2309.553043871876  Init btc: 0.13719717154311148
# buying 0.20722btc at 11145.525710572238
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20722btc at 11145.483835405917
# 2309.567160372814 remaining usdt
#
# ====
#
# USDT: 2309.567160372814  Init btc: 0.13719717154311148
# buying 0.20706btc at 11153.863563053083
# 0.0 remaining usdt
#
# ====
#
# Selling 0.20706btc at 11132.225378584219
# 2305.0385868896483 remaining usdt
#
# ====
#
# USDT: 2305.0385868896483  Init btc: 0.13719717154311148
#
# ========================
#
# Step: 16914
# BTC Balance: 0.0
# USDT Balance: 2305.0385868896483
# Max usdt: 2335.213575424906
# Max btc: 0.20732
# Max btc at current price: 2084.6357712
# Profit: 1.0
